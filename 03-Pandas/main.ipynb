# %%
import pandas as pd
import numpy as np
import random


dicto = {1:'a',2:'b',3:'c'}

listo = np.array(['a','b','c'])

a = pd.Series(listo,dicto)

# %%
a
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(random.randn(),)
